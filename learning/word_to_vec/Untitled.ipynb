# %%
import pandas as pd
import numpy as np

# %%
import gensim 
import os

# %%
from nltk import sent_tokenize
from gensim.utils import simple_preprocess

# %%
story=[]
for filename in os.listdir('data'):
    
    f=open(os.path.join("data",filename))
    corpus=f.read()
    raw_sent=sent_tokenize(corpus)
    for sent in raw_sent:
        story.append(simple_preprocess(sent))

# %%
len(story)
# Out:
# 145018

# %%
model = gensim.models.Word2Vec(
    window=10,
    min_count=2
)

# %%
model.build_vocab(story)

# %%
model.build_vocab(story)

# %%
model.train(story, total_examples=model.corpus_count, epochs=model.epochs)
# Out:
# (6570144, 8628190)

# %%
model.wv.most_similar("daenerys")
# Out:
# [('stormborn', 0.8061994910240173),
#  ('targaryen', 0.77308189868927),
#  ('princess', 0.7515380382537842),
#  ('myrcella', 0.727083683013916),
#  ('unburnt', 0.720794677734375),
#  ('elia', 0.7167308330535889),
#  ('queen', 0.6911255121231079),
#  ('rhaegar', 0.6799337267875671),
#  ('dorne', 0.6637438535690308),
#  ('prince', 0.64128577709198)]

# %%
model.wv.doesnt_match(["jon","rikon","robb","arya","sansa","bran"])
# Out:
# 'jon'

# %%
model.wv["king"]
# Out:
# array([-0.20097752, -1.394704  ,  0.9524865 ,  0.5024221 ,  2.9305837 ,
#        -1.5949467 ,  0.566766  ,  2.4573882 , -1.4692972 , -2.625184  ,
#         1.812033  ,  1.0250905 , -3.9106135 , -3.345047  , -0.6101407 ,
#         1.1762182 ,  0.30761844, -2.5405674 , -1.8827379 , -0.18153097,
#        -1.5688807 , -1.2995757 ,  2.1477427 ,  2.3028247 ,  2.6010184 ,
#        -0.48668656,  2.6951325 , -0.6779942 , -0.06943519, -0.6382133 ,
#        -0.06426532,  1.4330978 ,  2.3279943 , -1.3748281 ,  0.6534671 ,
#        -2.2539413 , -0.22972693,  0.44370794, -1.7567548 , -2.4669957 ,
#        -2.9614081 , -1.1567131 , -0.8321329 , -0.9645932 ,  2.8343105 ,
#         0.7286188 , -1.8130196 ,  3.1569588 ,  1.8092936 , -0.47294787,
#         1.9399421 , -2.3302858 ,  0.00494352, -0.8826302 ,  1.9071656 ,
#        -0.42639202, -0.40189832,  3.3269804 , -2.6744237 , -2.1754491 ,
#         0.24705188, -2.706366  ,  1.408942  , -0.9777888 ,  3.510611  ,
#         1.5775416 ,  1.0554475 ,  1.239439  ,  1.2338274 ,  0.14909844,
#         0.99033266,  2.1070879 ,  0.6002931 ,  2.898805  , -1.6269034 ,
#        -2.235848  ,  1.8724279 , -3.2707539 , -1.1471176 , -1.0392694 ,
#         2.6694925 ,  3.6852782 ,  3.8459733 , -0.17089994, -0.4335318 ,
#         1.3577636 , -1.9238591 , -2.295978  ,  1.1172353 ,  2.3818884 ,
#        -0.3851025 , -2.9607663 ,  1.8458278 , -0.06543627, -2.4252467 ,
#         0.19489267, -1.0223671 , -0.7317793 ,  0.0688365 ,  0.02961186],
#       dtype=float32)

# %%
model.wv.similarity("arya","jon")
# Out:
# 0.45615375

# %%
model.wv.similarity("arya","sansa")
# Out:
# 0.85335255

# %%
model.wv.similarity("tywin","sansa")
# Out:
# 0.23067644

# %%
model.wv.get_normed_vectors().shape
# Out:
# (17453, 100)

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=3)

# %%
X=pca.fit_transform(model.wv.get_normed_vectors())

# %%
X.shape
# Out:
# (17453, 3)

# %%
import plotly.express as px

# %%
fig = px.scatter_3d(X[:100], x=0, y=1, z=2)
fig.show()
# Out:
# <div>                            <div id="83bf5893-96d8-4cab-8100-5fcbc3f1b351" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("